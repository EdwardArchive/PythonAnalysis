# %%
from selenium import webdriver as wd
from bs4 import BeautifulSoup
import time
import csv
import pandas as pd
from tqdm import tqdm_notebook
fw = open('comment.txt','w', encoding='utf8')
driver = wd.Chrome(executable_path="chromedriver.exe")  #크롬 작동을 제어하는 모듈
url = 'https://www.youtube.com/watch?v=ESvz3xOa9R0' #  댓글을 받고 싶은 주소
urltest = 'https://www.youtube.com/watch?v=LNIpr3efeeI'
driver.get(url)
time.sleep(6.0)

last_page_height = driver.execute_script("return document.documentElement.scrollHeight")
while True:
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(3.0)
    new_page_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_page_height == last_page_height:
        break
    last_page_height = new_page_height
html_source = driver.page_source
driver.close()

soup = BeautifulSoup(html_source, 'lxml')

youtube_user_IDs = soup.select('div#header-author > a > span')
youtube_comments = soup.select('yt-formatted-string#content-text')

str_youtube_userIDs = []
str_youtube_comments = []
for i in tqdm_notebook(range(len(youtube_user_IDs))):
    str_tmp = str(youtube_user_IDs[i].text)
# print(str_tmp)
    str_tmp = str_tmp.replace('\n', '')
    str_tmp = str_tmp.replace('\t', '')
    str_tmp = str_tmp.replace(' ','')
    str_youtube_userIDs.append(str_tmp)
    str_tmp = str(youtube_comments[i].text)
    str_tmp = str_tmp.replace('\n', '')
    str_tmp = str_tmp.replace('\t', '')
    str_tmp = str_tmp.replace(' ', ' ')
    str_youtube_comments.append(str_tmp)
data={}
for i in tqdm_notebook(range(len(str_youtube_userIDs))):
    #print(i+1,': ',str_youtube_userIDs[i],' : ', str_youtube_comments[i])
    data[str_youtube_userIDs[i]]=str_youtube_comments[i]
comments=pd.DataFrame(list(data.items()),columns=["id","comments"])
comments.to_csv("data/comments(noaml).csv",encoding="utf-8-sig")

print("done")
# Out:
# HBox(children=(IntProgress(value=0, max=234), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=234), HTML(value='')))
# done

# %%
comments
# Out:
#                        id                                           comments
# 0                      동하                                       장첸 먹는 척만 함ㅋㅋ
# 1                   eikoS                    저정돈 아니어도 ㅈㄴ 크던데? ㅋㅋ 맛잇게 먹엇다 꺼ㅡ억
# 2                     김진석                크 고딩때 맨날 몬스터베이비사먹었는데. 몬스터베이비 장성한것보소
# 3                    떠망떠망  솔까 저정도로 크진 않은데 다른 프랜차이즈 버거보단 존내 큼 ㅋㅋㅋㅋㅋㅋ 세트 하나...
# 4                     이지석                             이건 버거가 큰게 아니라 얼굴이 작음거임
# 5            Na.Yun-homan      이제 종로2가 안가도 되겠네이제 종암동에 새로 생긴 버거킹갔다가, 요거 사먹어야지
# 6               GomGrills                          먹어봤는데 양이 넘 많드라 ㄷㄷ 먹을만하긴 함
# 7                  김씨황씨TV                                            너무커!ㅋㅋㅋ
# 8                      옹야                            진짜 저렇게 얼굴 파묻고 먹을 수 있음??
# 9                InsungJo                                     방금 먹었는데 이거 맛있슴
# 10                    첫바풍                                      썸네일 실화?엌ㅋㅋㅋㅋㅋ
# 11                 식기세척기식                                      저거 먹어봤는데 맛없던데
# 12                 ᅵᅵᅵᅵᅵᅵ                                      이거 진짜 개꿀맛 ㅋㅋㅋ
# 13                   박모퉁이                                     설마..저렇게 놀랬을라구~
# 14                    요썬업                몬스터와퍼 존맛ㅋㅋㅋ 해장할때 꿀이던데맥날보다 훠~얼씬 괜찮던데
# 15                     익명                                             와 ㅂㄷㄷ♥
# 16                    김조이                         퀄리티보소ㅋㅋㅋ...아찔해 새로워...치명적이야
# 17               mashmero        몬스터 베이비 상위 호환ㅋㅋㅋ 이걸로 고기 한번에 다 먹을 수 있어서 더 좋음
# 18               구독하면여친생김                                              윤계상이~
# 19             DagyeomLee  믿고 먹는 버거!!!!!!!!! 힝힝 넘나 기다렸음 ㅠㅠㅠ 괴물버거 왕왕 머글테다!...
# 20                  안녕하세요                                           미국인줄ㅋㅋㅋㅋ
# 21                   AAHH     난이거 존맛이던데ㅋㅋㅋ 이거 세트로 시켰는데 배불러서 남김 자존심상해 더 분발해야지
# 22               JudyJang                                         윤계상♡♡♡♡♡♡♡
# 23               SejinLee                                         호오 맛있겟다 ㅠㅠ
# 24               찌예는네짤[쥰]                                      하하...하하하하하핳..
# 25                  &0011                        ㅋㅋㅋ 버거킹 몬스터 와퍼 게임에 음식으로 있는데
# 26             SUNGMIYOON                                     이거 지짜 맛있는데!!핵맛
# 27                    진명종                                          버거킹 맛있어요!
# 28                  RichJ                                            넘넘 맛있었다
# 29                  ㅤㅤㅤㅤ슈                                   약간 클거같은데 허위같아요ㅜㅜ
# ..                    ...                                                ...
# 201                   동네형                             처먹지도 못하면서 먹는척하면먼소리할거같니
# 202                  남김영석          사먹었는데 진짜 크더라 맥이랑   롯   꺼는   못먹겠다 버거킹꺼먹다보니
# 203                   하승래                                       광고즘 그맘해라좀! !
# 204                   방공호                                   버거가 사람 잡아먹는거 같은데
# 205                   주연서                                               마싯게따
# 206             cookiejar  시골이라 우리지역에 버거킹 2개밖에없어서 경쟁장사 안하다보니까 퀄 개구림,, 식어서...
# 207                  뱃살살뱃                             저거 쟝첸 얼굴이 작은거임 버거 별로인큼
# 208                   민준김                                       ㅈㄴ 맛나게 생겼네..
# 209          SeonghoJeong                                            디아블로...
# 210                 무지개69                                       이거 사 먹었는데 꿀맛
# 211                   한승훈    ???나만 존나 만족하고 먹었나?? 크기도 맛도 종나 괜찮던데?? 댓글 반응 신기..
# 212                    에반                                              칠천구배건
# 213                    귀찮  근데 버거들이 다 거기서 거기같더라 맛은 다르지만 크기는 그냥 두깨7cm 지름12c...
# 214  로또1등되서꽃길걷자로또1등되서꽃길걷자                                       입에 드가나 저게 ㄷㄷ
# 215                    노루                                           디아블로...?
# 216              구독해줭베댓되면                                    이거 개맛잇음 ㄹㅇ 먹어보셈
# 217                   고서진                                           호우 듀랑고쿠폰
# 218                박현규빡빡이         버거킹 집근처에 생기면 좋겠다... 버거킹 ㅈㄴ 멀어서 맨날 롯데리아 가는데
# 219                 스톰트루퍼                                          진짜 졸라 맛있음
# 220                    중존                                  몬스터와퍼 버거 챌린지 가즈아ㅏ
# 221                   다현이                                  썸네일 보고 놀라서 들어온 1인
# 222                    수빈                                           장첸 오랜만이넹
# 223                   김동환                            아씨바 못참겠다 버거킹 몇시에 문여냐 시바
# 224             sunfrisat                   예쁜이녕님 영상 보는데 왜 자꾸 이 영상이 나오는거냐 ㅠᆞ
# 225                 공주부계`                     저거한입먹어도 묻기만하고 빵만살짝먹을듯 ㅋㅋㅋㅋㅋㅋㅋㅋ
# 226                    고래               세트 시켰는데 뭔 9천원이나 해?싶었음.한입 무는순간 9천원 ㅇㅈ
# 227                    진영                                          햄버거 대무리이네
# 228              ChrisLee                         겁나맛있음단지 치킨패티가 닭가슴살인건 좀 아쉬움
# 229          성태형을닮은잘생긴낙타씨                                                 Dh
# 230                    명무            햄버거는 버거킹 맘스터치만감. 롯데리아가는 사람하곤 상종을 하면 안댐.
#
# [231 rows x 2 columns]
